# %%
rec={1:'priyanshu',2:'mukul',3:'vinita'}
attendence={'01/07/23':{1:'present',2:'absent',3:'present'}}
#-----to add the student-----
def adstu(roll,name):
    rec[roll]=name
    return rec

#----mark attendence----
def mattend(date,roll,status):
    if date not in attendence:
           attendence[date]={}
    attendence[date][roll]=status
    return attendence

 

counter=0
t=0
c=['priyansh',2608]
while (t!=2):
    print("hello!!")
    print("1. Login ")
    print("2. exit")
    i=int(input("enter your choice"))
    t=i
    while (counter!=3):
        if i==1:
            u=input("enter valid username:")
            p=int(input("enter your password:"))
            if u==c[0] and p==c[1]:
                print("Login successful")
                choice=0
                print("Hello!!",u,"What do you want to do toady???")
                while (choice!=7):
                    print("1.add a student\n2.View student record\n3.Update records\n4.Delete record\n5.mark attendence\n6. view attendence\n 7.exit")
                    ch=int(input("enter ur choice:"))
                    choice=ch
                    if ch==1:
                        roll=int(input("enter student roll no"))
                        name=input("enter student name")
                        adstu(roll,name)
                        print("student added succesfully")
                    elif ch==2:
                        print("Student record=",rec)
                    elif ch==3:
                        roll=int(input("enter the roll no of student"))
                        name=input("enter the updated name")
                        rec.update([(roll,name)])
                        print("name of student updated successfully!!!")
                    elif ch==4:
                        roll=int(input("enter the roll no of student"))
                        del rec[roll]
                        print("Required student record is deleted!!!!")
                    elif ch==5:
                        date=input("enter date in dd/mm/yy")
                        roll=int(input("enter the roll no of student"))
                        status=input("is students present or absent??")
                        mattend(date,roll,status)
                        print("Attendence marked succesfully!!!!")
                    elif ch==6:
                        date=input("enter date in dd/mm/yy")
                        roll=int(input("enter the roll no of student"))
                        print("roll no",roll,"is",attendence[date][roll],"on",date)
                    else:
                        print("exiting....")
                        break

            else:
                print("login Failed") 
                counter+=1 
        else:
            print("Exiting the application.....")
            break
